# %%
import requests
import json
from bs4 import BeautifulSoup
import pandas
from selenium import webdriver 



# get the urls
root_url = "https://www.immoweb.be/en/search/house/for-sale"

response = requests.get(root_url, headers=headers)
html_text = response.text
    

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}
# parse HTML
html_text = requests.get(root_url, headers = headers).text
soup = BeautifulSoup(html_text, "html.parser")
bedroom_elements = soup.find_all("span", class_="card__title")
bedroom_list = []

for elem in bedroom_elements:
    text = elem.get_text(strip=True)
    if "bedroom" in text.lower():
        bedroom_list.append(text)

print("Bedrooms found:")
print(bedroom_list)
# Out:
# Bedrooms found:
# []
